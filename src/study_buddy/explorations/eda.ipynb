# %%
import lancedb
from backend.constants import VECTOR_DB_PATH

db = lancedb.connect(str(VECTOR_DB_PATH.as_posix()))

VECTOR_DB_PATH.as_posix()
# Out:
# 'C:/Users/Lilit/Documents/GitHub/Fullstack_LLMops_Project/src/study_buddy/data/lancedb'

# %%
db["LectureTranscript"].to_pandas()
