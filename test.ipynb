# %%
import lancedb

db = lancedb.connect("data/lancedb")
db["LectureTranscript"].to_pandas()
# Out:
#                                         document_name  \
# 0   An introduction to the vector database LanceDB.md
# 1            Azure static web app deploy react app.md
# 2      Course structure for Azure two weeks course.md
# 3                             docker setup windows.md
# 4   FastAPI and scikit-learn API connect to stream...
# 5                               How does LLM work_.md
# 6   Logistic regression hands on with scikit learn.md
# 7                       Logistic regression theory.md
# 8   Modern data stack - deploy dockerized dashboar...
# 9   Modern data stack - dockerize your data pipeli...
# 10                             Packaging in python.md
# 11                               pandas_read_excel.md
# 12                           Pydantic fundamentals.md
# 13  Pydantic with gemini to structure output in a ...
# 14                              pydanticAI chatbot.md
# 15  PydanticAI fundamentals - outputting structure...
# ...
